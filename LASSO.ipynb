# %%
import datetime
import yfinance as yf
import pandas as pd
import numpy as np
import six

# %%
startDate = datetime.date(2015,4,1)
endDate = datetime.date(2024,10,1)

# %%
## Dow Jones Indutrial Average Index Composition
DJI  = {
          datetime.date(2015,4,1) : {
                                      "x1": "MMM",  # 3M Company
                                      "x2": "GE",   # General Electric Company
                                      "x3": "NKE",  # Nike, Inc.
                                      "x4": "AXP",  # American Express Company
                                      "x5": "GS",   # The Goldman Sachs Group, Inc.
                                      "x6": "PFE",  # Pfizer Inc.
                                      "x7": "AAPL", # Apple Inc.
                                      "x8": "HD",   # The Home Depot, Inc.
                                      "x9": "PG",   # The Procter & Gamble Company
                                      "x10": "BA",  # The Boeing Company
                                      "x11": "INTC",# Intel Corporation
                                      "x12": "TRV", # The Travelers Companies, Inc.
                                      "x13": "CAT", # Caterpillar Inc.
                                      "x14": "IBM", # International Business Machines Corporation
                                      "x15": "UNH", # UnitedHealth Group Inc.
                                      "x16": "CVX", # Chevron Corporation
                                      "x17": "JNJ", # Johnson & Johnson
                                      "x18": "DIS",  # The Walt Disney Company
                                      "x19": "CSCO",# Cisco Systems, Inc.
                                      "x20": "JPM", # JPMorgan Chase & Co.
                                      "x21": "VZ",  # Verizon Communications Inc.
                                      "x22": "KO",  # The Coca-Cola Company
                                      "x23": "MCD", # McDonald's Corporation
                                      "x24": "V",   # Visa Inc.
                                      "x25": "DD",  # E.I. du Pont de Nemours & Company
                                      "x26": "MRK", # Merck & Co., Inc.
                                      "x27": "WMT", # Wal-Mart Stores, Inc.
                                      "x28": "XOM", # Exxon Mobil Corporation
                                      "x29": "MSFT",# Microsoft Corporation
                                      "x30": "UTX", # United Technologies Corporation
                                  },

          datetime.date(2017,9,1):{
                                        "x1": "MMM",  # 3M Company
                                        "x2": "GE",   # General Electric Company
                                        "x3": "NKE",  # Nike, Inc.
                                        "x4": "AXP",  # American Express Company
                                        "x5": "GS",   # The Goldman Sachs Group, Inc.
                                        "x6": "PFE",  # Pfizer Inc.
                                        "x7": "AAPL", # Apple Inc.
                                        "x8": "HD",   # The Home Depot, Inc.
                                        "x9": "PG",   # The Procter & Gamble Company
                                        "x10": "BA",  # The Boeing Company
                                        "x11": "INTC",# Intel Corporation
                                        "x12": "TRV", # The Travelers Companies, Inc.
                                        "x13": "CAT", # Caterpillar Inc.
                                        "x14": "IBM", # International Business Machines Corporation
                                        "x15": "UNH", # UnitedHealth Group Inc.
                                        "x16": "CVX", # Chevron Corporation
                                        "x17": "JNJ", # Johnson & Johnson
                                        "x18": "DIS",  # The Walt Disney Company
                                        "x19": "CSCO",# Cisco Systems, Inc.
                                        "x20": "JPM", # JPMorgan Chase & Co.
                                        "x21": "VZ",  # Verizon Communications Inc.
                                        "x22": "KO",  # The Coca-Cola Company
                                        "x23": "MCD", # McDonald's Corporation
                                        "x24": "V",   # Visa Inc.
                                        "x25": "DWDP",# DowDuPont Inc. (formerly E.I. du Pont de Nemours & Company)
                                        "x26": "MRK", # Merck & Co., Inc.
                                        "x27": "WMT", # Wal-Mart Stores, Inc.
                                        "x28": "XOM", # Exxon Mobil Corporation
                                        "x29": "MSFT",# Microsoft Corporation
                                        "x30": "UTX", # United Technologies Corporation
                                     },

          datetime.date(2018,6,26): {
                                      'x1': 'MMM',                # 3M Company
                                      'x2': 'GS',                 # The Goldman Sachs Group, Inc.
                                      'x3': 'PFE',                # Pfizer Inc.
                                      'x4': 'AXP',                # American Express Company
                                      'x5': 'HD',                 # The Home Depot, Inc.
                                      'x6': 'PG',                 # The Procter & Gamble Company
                                      'x7': 'AAPL',               # Apple Inc.
                                      'x8': 'INTC',               # Intel Corporation
                                      'x9': 'TRV',                # The Travelers Companies, Inc.
                                      'x10': 'BA',                # The Boeing Company
                                      'x11': 'IBM',               # International Business Machines Corporation
                                      'x12': 'UNH',               # UnitedHealth Group Incorporated
                                      'x13': 'CAT',               # Caterpillar Inc.
                                      'x14': 'JNJ',               # Johnson & Johnson
                                      'x15': 'DIS',                # The Walt Disney Company
                                      'x16': 'CVX',               # Chevron Corporation
                                      'x17': 'JPM',               # JPMorgan Chase & Co.
                                      'x18': 'VZ',                # Verizon Communications Inc.
                                      'x19': 'CSCO',              # Cisco Systems, Inc.
                                      'x20': 'MCD',               # McDonald's Corporation
                                      'x21': 'V',                 # Visa Inc.
                                      'x22': 'KO',                # The Coca-Cola Company
                                      'x23': 'MRK',               # Merck & Co., Inc.
                                      'x24': 'WBA',               # Walgreens Boots Alliance, Inc.
                                      'x25': 'DWDP',              # DowDuPont Inc.
                                      'x26': 'MSFT',              # Microsoft Corporation
                                      'x27': 'WMT',               # Walmart Inc.
                                      'x28': 'XOM',               # Exxon Mobil Corporation
                                      'x29': 'NKE',               # Nike, Inc.
                                      'x30': 'UTX',               # United Technologies Corporation

                                  },

          datetime.date(2019,4,2): {  'x1':'MMM',                #3M Company
                                      'x2':'GS',                 #The Goldman Sachs Group, Inc.
                                      'x3':'PFE',                #Pfizer Inc.
                                      'x4':'AXP',                #American Express Company
                                      'x5':'HD',                 #The Home Depot, Inc.
                                      'x6':'PG',                 #The Procter & Gamble Company
                                      'x7':'AAPL',               #Apple Inc.
                                      'x8':'INTC',               #Intel Corporation
                                      'x9':'TRV',                #The Travelers Companies, Inc.
                                      'x10':'BA',                #The Boeing Company
                                      'x11':'IBM',               #International Business Machines Corporation
                                      'x12':'UNH',               #UnitedHealth Group Incorporated
                                      'x13':'CAT',               #Caterpillar Inc.
                                      'x14':'JNJ',               #Johnson & Johnson
                                      'x15':'DIS',                #The Walt Disney Company
                                      'x16':'CVX',               #Chevron Corporation
                                      'x17':'JPM',               #JPMorgan Chase & Co.
                                      'x18':'VZ',                #Verizon Communications Inc.
                                      'x19':'CSCO',              #Cisco Systems, Inc.
                                      'x20':'MCD',               #McDonald's Corporation
                                      'x21':'V',                 #Visa Inc.
                                      'x22':'KO',                #The Coca-Cola Company
                                      'x23':'MRK',               #Merck & Co., Inc.
                                      'x24':'WBA',               #Walgreens Boots Alliance, Inc.
                                      'x25':'DOW',               #Dow Inc.
                                      'x26':'MSFT',              #Microsoft Corporation
                                      'x27':'WMT',               #Walmart Inc.
                                      'x28':'XOM',               #Exxon Mobil Corporation
                                      'x29':'NKE',               #Nike, Inc.
                                      'x30':'UTX',               #United Technologies Corporation
                                  },

          datetime.date(2020,4,6) :  {
                                      'x1':'MMM',                #3M Company
                                      'x2':'GS',                 #The Goldman Sachs Group, Inc.
                                      'x3':'PFE',                #Pfizer Inc.
                                      'x4':'AXP',                #American Express Company
                                      'x5':'HD',                 #The Home Depot, Inc.
                                      'x6':'PG',                 #The Procter & Gamble Company
                                      'x7':'AAPL',               #Apple Inc.
                                      'x8':'INTC',               #Intel Corporation
                                      'x9':'RTX',                #Raytheon Technologies Corporation
                                      'x10':'BA',                #The Boeing Company
                                      'x11':'IBM',               #International Business Machines Corporation
                                      'x12':'TRV',               #The Travelers Companies, Inc.
                                      'x13':'CAT',               #Caterpillar Inc.
                                      'x14':'JNJ',               #Johnson & Johnson
                                      'x15':'UNH',               #UnitedHealth Group Incorporated
                                      'x16':'CVX',               #Chevron Corporation
                                      'x17':'JPM',               #JPMorgan Chase & Co.
                                      'x18':'VZ',                #Verizon Communications Inc.
                                      'x19':'CSCO',              #Cisco Systems, Inc.
                                      'x20':'MCD',               #McDonald's Corporation
                                      'x21':'V',                 #Visa Inc.
                                      'x22':'KO',                #The Coca-Cola Company
                                      'x23':'MRK',               #Merck & Co., Inc.
                                      'x24':'WBA',               #Walgreens Boots Alliance, Inc.
                                      'x25':'DOW',               #Dow Inc.
                                      'x26':'MSFT',              #Microsoft Corporation
                                      'x27':'WMT',               #Walmart Inc.
                                      'x28':'XOM',               #Exxon Mobil Corporation
                                      'x29':'NKE',               #Nike, Inc.
                                      'x30':'DIS'                #The Walt Disney Company
                                       },

          datetime.date(2020,8,31): {
                                      'x1':'MMM',                #3M Company
                                      'x2':'GS',                 #The Goldman Sachs Group, Inc.
                                      'x3':'NKE',                #Nike, Inc.
                                      'x4':'AXP',                #American Express Company
                                      'x5':'HD',                 #The Home Depot, Inc.
                                      'x6':'PG',                 #The Procter & Gamble Company
                                      'x7':'AMGN',               #Amgen Inc.
                                      'x8':'HON',                #Honeywell International Inc.
                                      'x9':'CRM',                #Salesforce, Inc.
                                      'x10':'AAPL',              #Apple Inc.
                                      'x11':'INTC',              #Intel Corporation
                                      'x12':'TRV',               #The Travelers Companies, Inc.
                                      'x13':'BA',                #The Boeing Company
                                      'x14':'IBM',               #International Business Machines Corporation
                                      'x15':'UNH',               #UnitedHealth Group Incorporated
                                      'x16':'CAT',               #Caterpillar Inc.
                                      'x17':'JNJ',               #Johnson & Johnson
                                      'x18':'VZ',                #Verizon Communications Inc.
                                      'x19':'CVX',               #Chevron Corporation
                                      'x20':'JPM',               #JPMorgan Chase & Co.
                                      'x21':'V',                 #Visa Inc.
                                      'x22':'CSCO',              #Cisco Systems, Inc.
                                      'x23':'MCD',               #McDonald's Corporation
                                      'x24':'WBA',               #Walgreens Boots Alliance, Inc.
                                      'x25':'KO',                #The Coca-Cola Company
                                      'x26':'MRK',               #Merck & Co., Inc.
                                      'x27':'WMT',               #Walmart Inc.
                                      'x28':'DOW',               #Dow Inc.
                                      'x29':'MSFT',              #Microsoft Corporation
                                      'x30':'DIS'                #The Walt Disney Company
                                     },

          datetime.date(2024,2,26) : {
                                      'x1':'MMM',                #3M Company
                                      'x2':'DOW',                #Dow Inc.
                                      'x3':'MSFT',               #Microsoft Corporation
                                      'x4':'AMZN',               #Amazon.com, Inc.
                                      'x5':'GS',                 #The Goldman Sachs Group, Inc.
                                      'x6':'NKE',                #Nike, Inc.
                                      'x7':'AXP',                #American Express Company
                                      'x8':'HD',                 #The Home Depot, Inc.
                                      'x9':'PG',                 #The Procter & Gamble Company
                                      'x10':'AMGN',              #Amgen Inc.
                                      'x11':'HON',               #Honeywell International Inc.
                                      'x12':'CRM',               #Salesforce, Inc.
                                      'x13':'AAPL',              #Apple Inc.
                                      'x14':'INTC',              #Intel Corporation
                                      'x15':'TRV',               #The Travelers Companies, Inc.
                                      'x16':'BA',                #The Boeing Company
                                      'x17':'IBM',               #International Business Machines Corporation
                                      'x18':'UNH',               #UnitedHealth Group Incorporated
                                      'x19':'CAT',               #Caterpillar Inc.
                                      'x20':'JNJ',               #Johnson & Johnson
                                      'x21':'VZ',                #Verizon Communications Inc.
                                      'x22':'CVX',               #Chevron Corporation
                                      'x23':'JPM',               #JPMorgan Chase & Co.
                                      'x24':'V',                 #Visa Inc.
                                      'x25':'CSCO',              #Cisco Systems, Inc.
                                      'x26':'MCD',               #McDonald's Corporation
                                      'x27':'WMT',               #Walmart Inc.
                                      'x28':'KO',                #The Coca-Cola Company
                                      'x29':'MRK',               #Merck & Co., Inc.
                                      'x30':'DIS'                #The Walt Disney Company
                                      }
}

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
def loadData( index = 'DJI' ):
  ''' loads initial data '''
  ##url = 'https://raw.githubusercontent.com/amparogg/CapstoneProject_WQU/refs/heads/main/dowjones.csv?token=GHSAT0AAAAAACY7TSTCKL4JGYYQVE2KLIG2ZYT5CBA'
  ##df = pd.read_csv(url,index_col=0)
  df = pd.read_csv('/content/gdrive/MyDrive/WQU Capstone/dowjones.csv', index_col=0)

  ## converting index into datetime
  strIndex = list(df.index)
  dateIndex = []
  for dateString in strIndex:
    dateInd = datetime.datetime.strptime(dateString, '%d-%m-%Y').date()
    dateIndex.append( dateInd )

  df.index = dateIndex
  df.head()
  return df

# %%
def generateRollPeriodInfoDict( df ):
  ''' generates rollPeriods along with relevant lookback periods '''
  ### finding first business day and last business day of the month
  ### these dates would serve as roll period dates later

  dates = list(df.index)
  dateDf = pd.DataFrame( dates, columns = ['date'] )

  ## convert to datetime (if not already)
  dateDf['date'] = pd.to_datetime( dateDf['date'] )
  dateDf.set_index('date', inplace=True)

  startOfMonth = dateDf.resample('BMS').first()  ## Business Month Start
  endOfMonth = dateDf.resample('BME').first()    ## Business Month End

  dateList =  pd.concat([startOfMonth, endOfMonth]).drop_duplicates().sort_index()
  startEndDates = dateList.index.date.tolist()

  ### rollPeriodDict contains info data for a particular roll period
  ### pre-COVID period, rolling every two month and lookback is 6M
  ### COVID period (post cutoffDate), rolling every month and lookback is 3M

  cutOffDate = datetime.date(2020,2,3)  ### marks the onset of COVID regime

  rollPeriodInfoDict = {}
  preCovidOffset = 12  ## 6 months lookback
  postCovidOffset = 6  ## 3 months lookback

  ## preCovid
  for i in range(12,116,4):
    rollPeriodInfoDict[(startEndDates[i], startEndDates[i+3])] = {'start': startEndDates[i-preCovidOffset], 'end': startEndDates[i-1], 'period' : 'preCovid'}

  ## postCovid
  for i in range(116,len(startEndDates)-1,2):
    rollPeriodInfoDict[(startEndDates[i], startEndDates[i+1])] = {'start': startEndDates[i-postCovidOffset], 'end': startEndDates[i-1], 'period' : 'postCovid'}

  return rollPeriodInfoDict

# %%
def generateRebalDates( index, startDate, endDate ):
  ''' generates the dataframe for the specified startDate and endDate '''
  indexRebalDates = list(DJI.keys())

  def nearestSmallerDate( indexRebalDates, refStartDate ):
    ''' nearest SmallerDate for a given refStartDate among rebalDate '''
    nearestSmallerDate = None
    for date in indexRebalDates:
      if date < refStartDate:
        nearestSmallerDate = date
    return nearestSmallerDate

  baseRebalDate = [nearestSmallerDate( indexRebalDates, startDate )] if nearestSmallerDate( indexRebalDates, startDate ) is not None else []
  rebalDatesInRange = [date for date in indexRebalDates if startDate <= date <= endDate]
  rebalDates =  baseRebalDate + rebalDatesInRange
  return rebalDates


def generateComposition( index, rebalDates, startDate, endDate ):
  ''' generates the composition dataframe for specified startDate and endDate '''
  if len(rebalDates) == 1:
    commonStocks = list(index[rebalDates[0]].values())
    unionStocks = commonStocks
    diffStocksDict = {}
  else:
    commonStocks = []
    unionStocks = []
    for i in range(len(rebalDates)-1):
      commonStocks.append( set(index[rebalDates[i]].values()) & set(index[rebalDates[i+1]].values()) )
      unionStocks.append( set(index[rebalDates[i]].values()) | set(index[rebalDates[i+1]].values()) )
    commonStocks = list(commonStocks[0])
    unionStocks = list(unionStocks[0])
    diffStocks = [ stock for stock in unionStocks if stock not in commonStocks]
    diffStocksDict = {}
    for stock in diffStocks:
      diffStocksDict[stock] = [date for date in rebalDates if stock in index[date].values()]

  commonStockVariableMapping = {}
  for k in range(1,len(commonStocks)+1):
    commonStockVariableMapping['x'+str(k)] = commonStocks[k-1]
  return commonStocks, diffStocksDict, commonStockVariableMapping

def generateDataFrame( origDF, rollPeriod, rollInfo, index ):
  ''' generates the dataframe which goes into the calculation engine '''
  rebalDates = rollInfo['rebalDates']
  start = rollInfo['start']
  end = rollInfo['end']
  commonStocks = rollInfo['commonStocks']
  diffStocksDict = rollInfo['diffStocksDict']
  commonStockVariableMapping = rollInfo['commonStockVariableMapping']
  reverseMapping = {val:key for key,val in six.iteritems(commonStockVariableMapping)}

  columns = commonStocks
  df = origDF[start:end][commonStocks]
  mapping = []
  for stock in columns:
    mapping.append( reverseMapping[stock] )
  df.columns = mapping
  df['y'] = origDF[index].loc[start:end]
  return df

# %%
def selectSubset( rollPeriod, rollInfo, numStocks ):
  ''' initial subset selection via LARS (Least Angle Regression) '''
  initDf = rollInfo['df']
  initDf = initDf.dropna(axis=1)
  returns = initDf.pct_change(1) * 100
  returns = returns.dropna()
  X = returns[['x'+str(i) for i in range(1,returns.shape[1])]]
  y = returns['y']

  ## performing LARS regression
  from sklearn import linear_model

  alpha = 0.1
  dAlpha = 0.01
  reg = linear_model.LassoLars(alpha=alpha)
  reg.fit(X,y)
  if len(list(filter(lambda x:x!=0, reg.coef_))) <= numStocks:
    subSet = [ 'x'+str(i+1) for i in range(len(reg.coef_)) if reg.coef_[i]!=0]
  else:
    while len(list(filter(lambda x:x!=0, reg.coef_))) > numStocks:
      alpha += dAlpha
      reg = linear_model.LassoLars(alpha=alpha)
      reg.fit(X,y)

  subSet = [ 'x'+str(i+1) for i in range(len(reg.coef_)) if reg.coef_[i]!=0]
  return subSet, alpha, X, y

def linearRegBeta( subset, X, y):
  """ performs linear regression on the selected dataset """
  from sklearn import linear_model
  reg = linear_model.LinearRegression()
  reg.fit(X[subset],y)
  coeff = reg.coef_
  betas = dict(zip(subset, coeff))

  return betas

def getTrackingError( rollPeriod, rollInfo, subset, betaLasso ):
  ''' calculates tracking error based on Lasso subset selection '''
  baseIndexLevels = rollInfo['df']['y']
  baseIndexReturns = baseIndexLevels.pct_change(1)*100

  lassoIndexLevels = (rollInfo['df'][subset]* list(betaLasso.values())).sum(axis=1)
  lassoIndexReturns = lassoIndexLevels.pct_change(1)*100

  absDiffReturns =  abs( lassoIndexReturns - baseIndexReturns )
  absDiffReturns = absDiffReturns.dropna()
  trackingError = sum(absDiffReturns)/len(absDiffReturns) * 100  ## in bps
  return baseIndexLevels, lassoIndexLevels, trackingError

# %%
df = loadData()
rollPeriodInfoDict = generateRollPeriodInfoDict( df )
for rollPeriod, rollInfo in rollPeriodInfoDict.items():
  rebalDates = generateRebalDates( DJI, rollInfo['start'], rollInfo['end'] )
  rollPeriodInfoDict[ rollPeriod ]['rebalDates'] = rebalDates
  commonStocks, diffStocksDict, commonStockVariableMapping =  generateComposition( DJI, rebalDates, rollInfo['start'], rollInfo['end'])
  rollPeriodInfoDict[ rollPeriod ]['commonStocks'] = commonStocks
  rollPeriodInfoDict[ rollPeriod ]['diffStocksDict'] = diffStocksDict
  rollPeriodInfoDict[ rollPeriod ]['commonStockVariableMapping'] = commonStockVariableMapping
  rollPeriodInfoDict[ rollPeriod ]['df'] = generateDataFrame( df, rollPeriod, rollInfo, 'DJI')
  numStocks = 6
  subset, alpha, X, y = selectSubset( rollPeriod, rollInfo , numStocks)
  betaLasso = linearRegBeta(subset, X, y)
  baseIndexLevels, lassoIndexLevels, trackingError = getTrackingError( rollPeriod, rollInfo, subset, betaLasso )
  rollInfo['betaLasso'] = betaLasso
  rollInfo['lassoIndexLevels'] = lassoIndexLevels
  rollInfo['baseIndexLevels'] = baseIndexLevels
  rollInfo['trackingError'] = trackingError

# %%
preCovidTrackingError = []
postCovidTrackingError = []

for rollPeriod, rollInfo in rollPeriodInfoDict.items():
  if rollInfo['period'] == 'preCovid':
    preCovidTrackingError.append( rollInfo['trackingError'])
  else:
    postCovidTrackingError.append( rollInfo['trackingError'])

print( 'PreCovid Tracking Error:', sum(preCovidTrackingError)/len(preCovidTrackingError))
print( 'PostCovid Tracking Error:', sum(postCovidTrackingError)/len(postCovidTrackingError))
# Out:
# PreCovid Tracking Error: 43.07023052274
# PostCovid Tracking Error: 56.50877511972253

# %%
allStocks = list( df.columns )[1:]
stockSelectionFrequency = {'preCovid': {stock: 0 for stock in allStocks}, 'postCovid': {stock: 0 for stock in allStocks}}

for rollPeriod, rollInfo in rollPeriodInfoDict.items():
  betaLasso = list(rollInfo['betaLasso'].keys())
  commonStockVariableMapping = rollInfo['commonStockVariableMapping']
  selectedStocks = [commonStockVariableMapping[stock] for stock in betaLasso]

  for stock in selectedStocks:
    if rollInfo['period'] == 'preCovid':
      stockSelectionFrequency['preCovid'][stock] = stockSelectionFrequency['preCovid'].get(stock,0) + 1
    else:
      stockSelectionFrequency['postCovid'][stock] = stockSelectionFrequency['postCovid'].get(stock,0) + 1

# %%
import matplotlib.pyplot as plt
keys = list(stockSelectionFrequency['preCovid'].keys())
values = list(stockSelectionFrequency['preCovid'].values())


plt.bar(keys, values, color='skyblue')
plt.title('Frequency of Stocks Selected in LASSO preCovid')
plt.xlabel('Stocks')
plt.ylabel('Frequency')

# Show the plot
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.tight_layout()  # Adjust layout to make room for rotated labels
plt.show()

# %%
keys = list(stockSelectionFrequency['postCovid'].keys())
values = list(stockSelectionFrequency['postCovid'].values())


plt.bar(keys, values, color='skyblue')
plt.title('Frequency of Stocks Selected in LASSO postCovid')
plt.xlabel('Stocks')
plt.ylabel('Frequency')

# Show the plot
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.tight_layout()  # Adjust layout to make room for rotated labels
plt.show()

# %%
relevantPeriods = [(datetime.date(2015, 10, 1), datetime.date(2015, 11, 30)),
                    (datetime.date(2018, 4, 2), datetime.date(2018, 5, 31)),
                     (datetime.date(2020, 2, 3), datetime.date(2020,2,28)),
                    (datetime.date(2024, 9, 2), datetime.date(2024,9,30))]


for rollPeriod in relevantPeriods:
  rollInfo = rollPeriodInfoDict[rollPeriod]
  betaLasso = rollInfo['betaLasso']
  betaLassoStocks = {}
  commonStockVariableMapping = rollInfo['commonStockVariableMapping']
  for var in betaLasso:
    betaLassoStocks[ commonStockVariableMapping[var] ] = betaLasso[var]

  stocks =  list(betaLassoStocks.keys())
  betas = list(betaLassoStocks.values())
  plt.bar(stocks, betas, color='skyblue', width = 0.5)
  plt.title('Betas for LASSO Subset Selected from {} to {}'.format(rollPeriod[0], rollPeriod[1]))
  plt.xlabel('Stocks')
  plt.ylabel('Betas')

  # Show the plot
  plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
  plt.tight_layout()  # Adjust layout to make room for rotated labels
  plt.show()

# %%
## varying number of stocks and comparing tracking error
rollPeriodInfoDict = generateRollPeriodInfoDict( df )
numStocks = [6,8,10,12,14,16,18]
rollPeriodInfoDict
# Out:
# {(datetime.date(2015, 10, 1),
#   datetime.date(2015, 11, 30)): {'start': datetime.date(2015, 4, 1), 'end': datetime.date(2015, 9, 30), 'period': 'preCovid'},
#  (datetime.date(2015, 12, 1),
#   datetime.date(2016, 1, 29)): {'start': datetime.date(2015, 6, 1), 'end': datetime.date(2015, 11, 30), 'period': 'preCovid'},
#  (datetime.date(2016, 2, 1),
#   datetime.date(2016, 3, 31)): {'start': datetime.date(2015, 8, 3), 'end': datetime.date(2016, 1, 29), 'period': 'preCovid'},
#  (datetime.date(2016, 4, 1),
#   datetime.date(2016, 5, 31)): {'start': datetime.date(2015, 10, 1), 'end': datetime.date(2016, 3, 31), 'period': 'preCovid'},
#  (datetime.date(2016, 6, 1),
#   datetime.date(2016, 7, 29)): {'start': datetime.date(2015, 12, 1), 'end': datetime.date(2016, 5, 31), 'period': 'preCovid'},
#  (datetime.date(2016, 8, 1),
#   datetime.date(2016, 9, 30)): {'start': datetime.date(2016, 2, 1), 'end': datetime.date(2016, 7, 29), 'period': 'preCovid'},
#  (datetime.date(2016, 10, 3),
#   datetime.date(2016, 11, 30)): {'start': datetime.date(2016, 4, 1), 'end': datetime.date(2016, 9, 30), 'period': 'preCovid'},
#  (datetime.date(2016, 12, 1),
#   datetime.date(2017, 1, 31)): {'start': datetime.date(2016, 6, 1), 'end': datetime.date(2016, 11, 30), 'period': 'preCovid'},
#  (datetime.date(2017, 2, 1),
#   datetime.date(2017, 3, 31)): {'start': datetime.date(2016, 8, 1), 'end': datetime.date(2017, 1, 31), 'period': 'preCovid'},
#  (datetime.date(2017, 4, 3),
#   datetime.date(2017, 5, 31)): {'start': datetime.date(2016, 10, 3), 'end': datetime.date(2017, 3, 31), 'period': 'preCovid'},
#  (datetime.date(2017, 6, 1),
#   datetime.date(2017, 7, 31)): {'start': datetime.date(2016, 12, 1), 'end': datetime.date(2017, 5, 31), 'period': 'preCovid'},
#  (datetime.date(2017, 8, 1),
#   datetime.date(2017, 9, 29)): {'start': datetime.date(2017, 2, 1), 'end': datetime.date(2017, 7, 31), 'period': 'preCovid'},
#  (datetime.date(2017, 10, 2),
#   datetime.date(2017, 11, 30)): {'start': datetime.date(2017, 4, 3), 'end': datetime.date(2017, 9, 29), 'period': 'preCovid'},
#  (datetime.date(2017, 12, 1),
#   datetime.date(2018, 1, 31)): {'start': datetime.date(2017, 6, 1), 'end': datetime.date(2017, 11, 30), 'period': 'preCovid'},
#  (datetime.date(2018, 2, 1),
#   datetime.date(2018, 3, 30)): {'start': datetime.date(2017, 8, 1), 'end': datetime.date(2018, 1, 31), 'period': 'preCovid'},
#  (datetime.date(2018, 4, 2),
#   datetime.date(2018, 5, 31)): {'start': datetime.date(2017, 10, 2), 'end': datetime.date(2018, 3, 30), 'period': 'preCovid'},
#  (datetime.date(2018, 6, 1),
#   datetime.date(2018, 7, 31)): {'start': datetime.date(2017, 12, 1), 'end': datetime.date(2018, 5, 31), 'period': 'preCovid'},
#  (datetime.date(2018, 8, 1),
#   datetime.date(2018, 9, 28)): {'start': datetime.date(2018, 2, 1), 'end': datetime.date(2018, 7, 31), 'period': 'preCovid'},
#  (datetime.date(2018, 10, 1),
#   datetime.date(2018, 11, 30)): {'start': datetime.date(2018, 4, 2), 'end': datetime.date(2018, 9, 28), 'period': 'preCovid'},
#  (datetime.date(2018, 12, 3),
#   datetime.date(2019, 1, 31)): {'start': datetime.date(2018, 6, 1), 'end': datetime.date(2018, 11, 30), 'period': 'preCovid'},
#  (datetime.date(2019, 2, 1),
#   datetime.date(2019, 3, 29)): {'start': datetime.date(2018, 8, 1), 'end': datetime.date(2019, 1, 31), 'period': 'preCovid'},
#  (datetime.date(2019, 4, 1),
#   datetime.date(2019, 5, 31)): {'start': datetime.date(2018, 10, 1), 'end': datetime.date(2019, 3, 29), 'period': 'preCovid'},
#  (datetime.date(2019, 6, 3),
#   datetime.date(2019, 7, 31)): {'start': datetime.date(2018, 12, 3), 'end': datetime.date(2019, 5, 31), 'period': 'preCovid'},
#  (datetime.date(2019, 8, 1),
#   datetime.date(2019, 9, 30)): {'start': datetime.date(2019, 2, 1), 'end': datetime.date(2019, 7, 31), 'period': 'preCovid'},
#  (datetime.date(2019, 10, 1),
#   datetime.date(2019, 11, 29)): {'start': datetime.date(2019, 4, 1), 'end': datetime.date(2019, 9, 30), 'period': 'preCovid'},
#  (datetime.date(2019, 12, 2),
#   datetime.date(2020, 1, 31)): {'start': datetime.date(2019, 6, 3), 'end': datetime.date(2019, 11, 29), 'period': 'preCovid'},
#  (datetime.date(2020, 2, 3),
#   datetime.date(2020, 2, 28)): {'start': datetime.date(2019, 11, 1), 'end': datetime.date(2020, 1, 31), 'period': 'postCovid'},
#  (datetime.date(2020, 3, 2),
#   datetime.date(2020, 3, 31)): {'start': datetime.date(2019, 12, 2), 'end': datetime.date(2020, 2, 28), 'period': 'postCovid'},
#  (datetime.date(2020, 4, 1),
#   datetime.date(2020, 4, 30)): {'start': datetime.date(2020, 1, 1), 'end': datetime.date(2020, 3, 31), 'period': 'postCovid'},
#  (datetime.date(2020, 5, 1),
#   datetime.date(2020, 5, 29)): {'start': datetime.date(2020, 2, 3), 'end': datetime.date(2020, 4, 30), 'period': 'postCovid'},
#  (datetime.date(2020, 6, 1),
#   datetime.date(2020, 6, 30)): {'start': datetime.date(2020, 3, 2), 'end': datetime.date(2020, 5, 29), 'period': 'postCovid'},
#  (datetime.date(2020, 7, 1),
#   datetime.date(2020, 7, 31)): {'start': datetime.date(2020, 4, 1), 'end': datetime.date(2020, 6, 30), 'period': 'postCovid'},
#  (datetime.date(2020, 8, 3),
#   datetime.date(2020, 8, 31)): {'start': datetime.date(2020, 5, 1), 'end': datetime.date(2020, 7, 31), 'period': 'postCovid'},
#  (datetime.date(2020, 9, 1),
#   datetime.date(2020, 9, 30)): {'start': datetime.date(2020, 6, 1), 'end': datetime.date(2020, 8, 31), 'period': 'postCovid'},
#  (datetime.date(2020, 10, 1),
#   datetime.date(2020, 10, 30)): {'start': datetime.date(2020, 7, 1), 'end': datetime.date(2020, 9, 30), 'period': 'postCovid'},
#  (datetime.date(2020, 11, 2),
#   datetime.date(2020, 11, 30)): {'start': datetime.date(2020, 8, 3), 'end': datetime.date(2020, 10, 30), 'period': 'postCovid'},
#  (datetime.date(2020, 12, 1),
#   datetime.date(2020, 12, 31)): {'start': datetime.date(2020, 9, 1), 'end': datetime.date(2020, 11, 30), 'period': 'postCovid'},
#  (datetime.date(2021, 1, 1),
#   datetime.date(2021, 1, 29)): {'start': datetime.date(2020, 10, 1), 'end': datetime.date(2020, 12, 31), 'period': 'postCovid'},
#  (datetime.date(2021, 2, 1),
#   datetime.date(2021, 2, 26)): {'start': datetime.date(2020, 11, 2), 'end': datetime.date(2021, 1, 29), 'period': 'postCovid'},
#  (datetime.date(2021, 3, 1),
#   datetime.date(2021, 3, 31)): {'start': datetime.date(2020, 12, 1), 'end': datetime.date(2021, 2, 26), 'period': 'postCovid'},
#  (datetime.date(2021, 4, 1),
#   datetime.date(2021, 4, 30)): {'start': datetime.date(2021, 1, 1), 'end': datetime.date(2021, 3, 31), 'period': 'postCovid'},
#  (datetime.date(2021, 5, 3),
#   datetime.date(2021, 5, 31)): {'start': datetime.date(2021, 2, 1), 'end': datetime.date(2021, 4, 30), 'period': 'postCovid'},
#  (datetime.date(2021, 6, 1),
#   datetime.date(2021, 6, 30)): {'start': datetime.date(2021, 3, 1), 'end': datetime.date(2021, 5, 31), 'period': 'postCovid'},
#  (datetime.date(2021, 7, 1),
#   datetime.date(2021, 7, 30)): {'start': datetime.date(2021, 4, 1), 'end': datetime.date(2021, 6, 30), 'period': 'postCovid'},
#  (datetime.date(2021, 8, 2),
#   datetime.date(2021, 8, 31)): {'start': datetime.date(2021, 5, 3), 'end': datetime.date(2021, 7, 30), 'period': 'postCovid'},
#  (datetime.date(2021, 9, 1),
#   datetime.date(2021, 9, 30)): {'start': datetime.date(2021, 6, 1), 'end': datetime.date(2021, 8, 31), 'period': 'postCovid'},
#  (datetime.date(2021, 10, 1),
#   datetime.date(2021, 10, 29)): {'start': datetime.date(2021, 7, 1), 'end': datetime.date(2021, 9, 30), 'period': 'postCovid'},
#  (datetime.date(2021, 11, 1),
#   datetime.date(2021, 11, 30)): {'start': datetime.date(2021, 8, 2), 'end': datetime.date(2021, 10, 29), 'period': 'postCovid'},
#  (datetime.date(2021, 12, 1),
#   datetime.date(2021, 12, 31)): {'start': datetime.date(2021, 9, 1), 'end': datetime.date(2021, 11, 30), 'period': 'postCovid'},
#  (datetime.date(2022, 1, 3),
#   datetime.date(2022, 1, 31)): {'start': datetime.date(2021, 10, 1), 'end': datetime.date(2021, 12, 31), 'period': 'postCovid'},
#  (datetime.date(2022, 2, 1),
#   datetime.date(2022, 2, 28)): {'start': datetime.date(2021, 11, 1), 'end': datetime.date(2022, 1, 31), 'period': 'postCovid'},
#  (datetime.date(2022, 3, 1),
#   datetime.date(2022, 3, 31)): {'start': datetime.date(2021, 12, 1), 'end': datetime.date(2022, 2, 28), 'period': 'postCovid'},
#  (datetime.date(2022, 4, 1),
#   datetime.date(2022, 4, 29)): {'start': datetime.date(2022, 1, 3), 'end': datetime.date(2022, 3, 31), 'period': 'postCovid'},
#  (datetime.date(2022, 5, 2),
#   datetime.date(2022, 5, 31)): {'start': datetime.date(2022, 2, 1), 'end': datetime.date(2022, 4, 29), 'period': 'postCovid'},
#  (datetime.date(2022, 6, 1),
#   datetime.date(2022, 6, 30)): {'start': datetime.date(2022, 3, 1), 'end': datetime.date(2022, 5, 31), 'period': 'postCovid'},
#  (datetime.date(2022, 7, 1),
#   datetime.date(2022, 7, 29)): {'start': datetime.date(2022, 4, 1), 'end': datetime.date(2022, 6, 30), 'period': 'postCovid'},
#  (datetime.date(2022, 8, 1),
#   datetime.date(2022, 8, 31)): {'start': datetime.date(2022, 5, 2), 'end': datetime.date(2022, 7, 29), 'period': 'postCovid'},
#  (datetime.date(2022, 9, 1),
#   datetime.date(2022, 9, 30)): {'start': datetime.date(2022, 6, 1), 'end': datetime.date(2022, 8, 31), 'period': 'postCovid'},
#  (datetime.date(2022, 10, 3),
#   datetime.date(2022, 10, 31)): {'start': datetime.date(2022, 7, 1), 'end': datetime.date(2022, 9, 30), 'period': 'postCovid'},
#  (datetime.date(2022, 11, 1),
#   datetime.date(2022, 11, 30)): {'start': datetime.date(2022, 8, 1), 'end': datetime.date(2022, 10, 31), 'period': 'postCovid'},
#  (datetime.date(2022, 12, 1),
#   datetime.date(2022, 12, 30)): {'start': datetime.date(2022, 9, 1), 'end': datetime.date(2022, 11, 30), 'period': 'postCovid'},
#  (datetime.date(2023, 1, 2),
#   datetime.date(2023, 1, 31)): {'start': datetime.date(2022, 10, 3), 'end': datetime.date(2022, 12, 30), 'period': 'postCovid'},
#  (datetime.date(2023, 2, 1),
#   datetime.date(2023, 2, 28)): {'start': datetime.date(2022, 11, 1), 'end': datetime.date(2023, 1, 31), 'period': 'postCovid'},
#  (datetime.date(2023, 3, 1),
#   datetime.date(2023, 3, 31)): {'start': datetime.date(2022, 12, 1), 'end': datetime.date(2023, 2, 28), 'period': 'postCovid'},
#  (datetime.date(2023, 4, 3),
#   datetime.date(2023, 4, 28)): {'start': datetime.date(2023, 1, 2), 'end': datetime.date(2023, 3, 31), 'period': 'postCovid'},
#  (datetime.date(2023, 5, 1),
#   datetime.date(2023, 5, 31)): {'start': datetime.date(2023, 2, 1), 'end': datetime.date(2023, 4, 28), 'period': 'postCovid'},
#  (datetime.date(2023, 6, 1),
#   datetime.date(2023, 6, 30)): {'start': datetime.date(2023, 3, 1), 'end': datetime.date(2023, 5, 31), 'period': 'postCovid'},
#  (datetime.date(2023, 7, 3),
#   datetime.date(2023, 7, 31)): {'start': datetime.date(2023, 4, 3), 'end': datetime.date(2023, 6, 30), 'period': 'postCovid'},
#  (datetime.date(2023, 8, 1),
#   datetime.date(2023, 8, 31)): {'start': datetime.date(2023, 5, 1), 'end': datetime.date(2023, 7, 31), 'period': 'postCovid'},
#  (datetime.date(2023, 9, 1),
#   datetime.date(2023, 9, 29)): {'start': datetime.date(2023, 6, 1), 'end': datetime.date(2023, 8, 31), 'period': 'postCovid'},
#  (datetime.date(2023, 10, 2),
#   datetime.date(2023, 10, 31)): {'start': datetime.date(2023, 7, 3), 'end': datetime.date(2023, 9, 29), 'period': 'postCovid'},
#  (datetime.date(2023, 11, 1),
#   datetime.date(2023, 11, 30)): {'start': datetime.date(2023, 8, 1), 'end': datetime.date(2023, 10, 31), 'period': 'postCovid'},
#  (datetime.date(2023, 12, 1),
#   datetime.date(2023, 12, 29)): {'start': datetime.date(2023, 9, 1), 'end': datetime.date(2023, 11, 30), 'period': 'postCovid'},
#  (datetime.date(2024, 1, 1),
#   datetime.date(2024, 1, 31)): {'start': datetime.date(2023, 10, 2), 'end': datetime.date(2023, 12, 29), 'period': 'postCovid'},
#  (datetime.date(2024, 2, 1),
#   datetime.date(2024, 2, 29)): {'start': datetime.date(2023, 11, 1), 'end': datetime.date(2024, 1, 31), 'period': 'postCovid'},
#  (datetime.date(2024, 3, 1),
#   datetime.date(2024, 3, 29)): {'start': datetime.date(2023, 12, 1), 'end': datetime.date(2024, 2, 29), 'period': 'postCovid'},
#  (datetime.date(2024, 4, 1),
#   datetime.date(2024, 4, 30)): {'start': datetime.date(2024, 1, 1), 'end': datetime.date(2024, 3, 29), 'period': 'postCovid'},
#  (datetime.date(2024, 5, 1),
#   datetime.date(2024, 5, 31)): {'start': datetime.date(2024, 2, 1), 'end': datetime.date(2024, 4, 30), 'period': 'postCovid'},
#  (datetime.date(2024, 6, 3),
#   datetime.date(2024, 6, 28)): {'start': datetime.date(2024, 3, 1), 'end': datetime.date(2024, 5, 31), 'period': 'postCovid'},
#  (datetime.date(2024, 7, 1),
#   datetime.date(2024, 7, 31)): {'start': datetime.date(2024, 4, 1), 'end': datetime.date(2024, 6, 28), 'period': 'postCovid'},
#  (datetime.date(2024, 8, 1),
#   datetime.date(2024, 8, 30)): {'start': datetime.date(2024, 5, 1), 'end': datetime.date(2024, 7, 31), 'period': 'postCovid'},
#  (datetime.date(2024, 9, 2),
#   datetime.date(2024, 9, 30)): {'start': datetime.date(2024, 6, 3), 'end': datetime.date(2024, 8, 30), 'period': 'postCovid'}}

# %%
for n in numStocks:
  print( 'Running Simulations for numStocks:', n)

  for rollPeriod, rollInfo in rollPeriodInfoDict.items():
    rebalDates = generateRebalDates( DJI, rollInfo['start'], rollInfo['end'] )
    rollPeriodInfoDict[ rollPeriod ]['rebalDates'] = rebalDates
    commonStocks, diffStocksDict, commonStockVariableMapping =  generateComposition( DJI, rebalDates, rollInfo['start'], rollInfo['end'])
    rollPeriodInfoDict[ rollPeriod ]['commonStocks'] = commonStocks
    rollPeriodInfoDict[ rollPeriod ]['diffStocksDict'] = diffStocksDict
    rollPeriodInfoDict[ rollPeriod ]['commonStockVariableMapping'] = commonStockVariableMapping
    rollPeriodInfoDict[ rollPeriod ]['df'] = generateDataFrame( df, rollPeriod, rollInfo, 'DJI')

    subset, alpha, X, y = selectSubset( rollPeriod, rollInfo , n)  ## n is number of stocks
    betaLasso = linearRegBeta(subset, X, y)
    baseIndexLevels, lassoIndexLevels, trackingError = getTrackingError( rollPeriod, rollInfo, subset, betaLasso )
    rollInfo['betaLasso'] = betaLasso
    rollInfo['lassoIndexLevels'] = lassoIndexLevels
    rollInfo['baseIndexLevels'] = baseIndexLevels
    rollInfo['trackingError'] = trackingError
    preCovidTrackingError = []
    postCovidTrackingError = []

  for rollPeriod, rollInfo in rollPeriodInfoDict.items():
    if rollInfo['period'] == 'preCovid':
      preCovidTrackingError.append( rollInfo['trackingError'])
    else:
      postCovidTrackingError.append( rollInfo['trackingError'])
  print( 'Number of Stocks Selected', n)
  print( 'PreCovid Tracking Error:', sum(preCovidTrackingError)/len(preCovidTrackingError))
  print( 'PostCovid Tracking Error:', sum(postCovidTrackingError)/len(postCovidTrackingError))
# Out:
# Running Simulations for numStocks: 6
# Number of Stocks Selected 6
# PreCovid Tracking Error: 43.070230522739976
# PostCovid Tracking Error: 56.50877511972251
# Running Simulations for numStocks: 8
# Number of Stocks Selected 8
# PreCovid Tracking Error: 35.88847969610684
# PostCovid Tracking Error: 43.67140414667083
# Running Simulations for numStocks: 10
# <ipython-input-192-c60803522fb5>:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['y'] = origDF[index].loc[start:end]
# Number of Stocks Selected 10
# PreCovid Tracking Error: 31.606493886137805
# PostCovid Tracking Error: 34.766383042730425
# Running Simulations for numStocks: 12
# Number of Stocks Selected 12
# PreCovid Tracking Error: 26.855054627822103
# PostCovid Tracking Error: 28.2635263446144
# Running Simulations for numStocks: 14
# Number of Stocks Selected 14
# PreCovid Tracking Error: 24.080056993386286
# PostCovid Tracking Error: 24.05278425358011
# Running Simulations for numStocks: 16
# Number of Stocks Selected 16
# PreCovid Tracking Error: 21.775859033604053
# PostCovid Tracking Error: 20.761095328908613
# Running Simulations for numStocks: 18
# Number of Stocks Selected 18
# PreCovid Tracking Error: 20.356811998258042
# PostCovid Tracking Error: 18.567961632614583
